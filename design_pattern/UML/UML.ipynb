# %% [markdown]
# ### Directed Association
# A filled arrow with a line.
#
# **Class A** uses **ClassB** or an object of ClassB

# %%
from PIL import Image

Image.open("directed_association.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=683x263 at 0x1C9F84F7220>

# %% [markdown]
# ### Inheritance
#
# An Unfilled arrow, with a line pointing to the class that is being inherited

# %%
Image.open("inheritance.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=737x201 at 0x1C9F84F7C40>

# %% [markdown]
# ### A class that implements an Interface
#
# An unfilled arrow, with a dashed line pointing to the interface that is being implemented.
#
# A class that implements an interface must implement all of the methods declared in the interface.

# %%
Image.open("interface_implementation.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=794x445 at 0x1C9F84F6F50>

# %% [markdown]
# ### Aggregates
#
# An unfilled diamond with a line and arrow head
#
# Class A aggregates Class B.
#
# Library aggregates Books. Books and Library can exist independently of each other. Books can exist without the Library.

# %%
Image.open("aggregates.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=688x276 at 0x1C9F84F7A90>

# %% [markdown]
# ### Composition
#
# A filled diamon with a lin and arrow head
#
# Class A is composed of Class B
#
# Shirt can be composed of Pockets and other parts. But an Shirt is no longer really an
# shirt without its Pocket.

# %%
Image.open("composition.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=663x267 at 0x1C9F84F7460>
